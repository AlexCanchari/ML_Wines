# %% [markdown]
# # Cargando los datos

# %%
import pandas as pd

# %%
df = pd.read_csv('https://storage.googleapis.com/the_public_bucket/wine-clustering.csv')
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %% [markdown]
# ## Verificamos los tipos de datos y cantidad de nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
df.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(3,5,figsize=(15, 10))
fig.delaxes(axes[2,3])
fig.delaxes(axes[2,4])
fig.suptitle('Distribución de los atributos')
axes[0,0].hist(df[df.columns[0]])
axes[0,0].set_xlabel(df.columns[0])
axes[0,1].hist(df[df.columns[1]])
axes[0,1].set_xlabel(df.columns[1])
axes[0,2].hist(df[df.columns[2]])
axes[0,2].set_xlabel(df.columns[2])
axes[0,3].hist(df[df.columns[3]])
axes[0,3].set_xlabel(df.columns[3])
axes[0,4].hist(df[df.columns[4]])
axes[0,4].set_xlabel(df.columns[4])
axes[1,0].hist(df[df.columns[5]])
axes[1,0].set_xlabel(df.columns[5])
axes[1,1].hist(df[df.columns[6]])
axes[1,1].set_xlabel(df.columns[6])
axes[1,2].hist(df[df.columns[7]])
axes[1,2].set_xlabel(df.columns[7])
axes[1,3].hist(df[df.columns[8]])
axes[1,3].set_xlabel(df.columns[8])
axes[1,4].hist(df[df.columns[9]])
axes[1,4].set_xlabel(df.columns[9])
axes[2,0].hist(df[df.columns[10]])
axes[2,0].set_xlabel(df.columns[10])
axes[2,1].hist(df[df.columns[11]])
axes[2,1].set_xlabel(df.columns[11])
axes[2,2].hist(df[df.columns[12]])
axes[2,2].set_xlabel(df.columns[12])
plt.tight_layout()

# %%
fig, axes = plt.subplots(3,5,figsize=(15, 10))
fig.delaxes(axes[2,3])
fig.delaxes(axes[2,4])
fig.suptitle('Gráfico de cajas de los atributos')
axes[0,0].boxplot(df[df.columns[0]])
axes[0,0].set_xlabel(df.columns[0])
axes[0,1].boxplot(df[df.columns[1]])
axes[0,1].set_xlabel(df.columns[1])
axes[0,2].boxplot(df[df.columns[2]])
axes[0,2].set_xlabel(df.columns[2])
axes[0,3].boxplot(df[df.columns[3]])
axes[0,3].set_xlabel(df.columns[3])
axes[0,4].boxplot(df[df.columns[4]])
axes[0,4].set_xlabel(df.columns[4])
axes[1,0].boxplot(df[df.columns[5]])
axes[1,0].set_xlabel(df.columns[5])
axes[1,1].boxplot(df[df.columns[6]])
axes[1,1].set_xlabel(df.columns[6])
axes[1,2].boxplot(df[df.columns[7]])
axes[1,2].set_xlabel(df.columns[7])
axes[1,3].boxplot(df[df.columns[8]])
axes[1,3].set_xlabel(df.columns[8])
axes[1,4].boxplot(df[df.columns[9]])
axes[1,4].set_xlabel(df.columns[9])
axes[2,0].boxplot(df[df.columns[10]])
axes[2,0].set_xlabel(df.columns[10])
axes[2,1].boxplot(df[df.columns[11]])
axes[2,1].set_xlabel(df.columns[11])
axes[2,2].boxplot(df[df.columns[12]])
axes[2,2].set_xlabel(df.columns[12])
plt.tight_layout()
